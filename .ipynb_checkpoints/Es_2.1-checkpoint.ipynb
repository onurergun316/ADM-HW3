# %% [markdown]
# # Preprocessing

# %%
# Description of Full Metal Alchemist: Brotherood
query=" After a horrific alchemy experiment goes wrong in the Elric household, brothers Edward and Alphonse are left in a catastrophic new reality. Ignoring the alchemical principle banning human transmutation, the boys attempted to bring their recently deceased mother back to life. Instead, they suffered brutal personal loss: Alphonse's body disintegrated while Edward lost a leg and then sacrificed an arm to keep Alphonse's soul in the physical realm by binding it to a hulking suit of armor. The brothers are rescued by their neighbor Pinako Rockbell and her granddaughter Winry. Known as a bio-mechanical engineering prodigy, Winry creates prosthetic limbs for Edward by utilizing automail, a tough, versatile metal used in robots and combat armor. After years of training, the Elric brothers set off on a quest to restore their bodies by locating the Philosopher's Stone—a powerful gem that allows an alchemist to defy the traditional laws of Equivalent Exchange. As Edward becomes an infamous alchemist and gains the nickname Fullmetal, the boys' journey embroils them in a growing conspiracy that threatens the fate of the world."

# %%
from nltk.tokenize import RegexpTokenizer
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
nltk.download('stopwords')
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Leo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
Finaldata = pd.DataFrame(columns=['animeTitle','animeDescription'])
for i in range(1,10):
    anime_tsv = open(r'C:\Users\Leo\Documents\ADMHomework\ADM-HW3-master\tsv_files\anime_'+str(i)+'.tsv', 'r',encoding="utf8")
    data=pd.read_table(anime_tsv)[['animeTitle','animeDescription']]
    Finaldata=pd.merge(Finaldata,data,how='outer')

# %%
keywords = []
words=[]
for i in range(len(Finaldata.iloc[:,1])):
    query=Finaldata.iloc[i,1]
    
    # lowercase all the query
    query = query.lower()
    
    #Remove punctuation
    token = RegexpTokenizer(r'\w+')
    query=token.tokenize(query)
    
    #Remove stopwords
    query = [word for word in query if not word in stopwords.words()]
    
    #STEMMING using Snowball
    stemmer = SnowballStemmer("english")
    
    #we add every word stemmed to a list we created
    words.append([stemmer.stem(word) for word in query])
    for word in query:
        keywords.append(stemmer.stem(word))

# %%
# Take words only one time
keywords = set(keywords)

# %%
# Assign an integer to each different words
voc = {}
i=1
for word in keywords:
    voc.update({word:i})
    i+=1

# %%
# Assign to each integer value (the word's associated value) a list of document's names that contains that word
dic={}
for q in voc:
    l = []
    for i in range(len(words)):
        if q in words[i]:
            l.append('anime_'+str(i+1))
    dic.update({voc[q]:l})

# %%
keywords
# Out:
# {'150',
#  '2',
#  '3',
#  '5pb',
#  'abandon',
#  'absenc',
#  'acclaim',
#  'achiev',
#  'across',
#  'action',
#  'adapt',
#  'addit',
#  'adventur',
#  'afoot',
#  'ago',
#  'agre',
#  'aid',
#  'air',
#  'akihabara',
#  'akito',
#  'alarm',
#  'alchem',
#  'alchemi',
#  'alchemist',
#  'alien',
#  'alli',
#  'allianc',
#  'allow',
#  'along',
#  'alongsid',
#  'alphons',
#  'alter',
#  'altern',
#  'although',
#  'alway',
#  'amidst',
#  'anyth',
#  'apart',
#  'appear',
#  'aris',
#  'arlert',
#  'arm',
#  'armin',
#  'armor',
#  'around',
#  'ask',
#  'assassin',
#  'attach',
#  'attain',
#  'attempt',
#  'autocraci',
#  'automail',
#  'away',
#  'back',
#  'backstori',
#  'ban',
#  'banana',
#  'basement',
#  'battl',
#  'becom',
#  'befriend',
#  'behind',
#  'belief',
#  'beneath',
#  'best',
#  'bewild',
#  'beyond',
#  'bind',
#  'bio',
#  'bodi',
#  'bond',
#  'boy',
#  'brave',
#  'break',
#  'breakthrough',
#  'bring',
#  'broke',
#  'brother',
#  'brutal',
#  'build',
#  'burden',
#  'captur',
#  'carv',
#  'cash',
#  'casualti',
#  'catastroph',
#  'chain',
#  'challeng',
#  'chan',
#  'chang',
#  'charact',
#  'cheek',
#  'chief',
#  'child',
#  'childhood',
#  'chines',
#  'circumst',
#  'citi',
#  'claim',
#  'clan',
#  'clash',
#  'climb',
#  'cling',
#  'clock',
#  'combat',
#  'come',
#  'commot',
#  'companionship',
#  'complet',
#  'concret',
#  'confound',
#  'confus',
#  'connect',
#  'conquer',
#  'conspiraci',
#  'contend',
#  'continu',
#  'contrapt',
#  'convinc',
#  'corp',
#  'could',
#  'countless',
#  'courtesan',
#  'crash',
#  'creat',
#  'creatur',
#  'crew',
#  'crimin',
#  'crise',
#  'critic',
#  'crumbl',
#  'curs',
#  'danger',
#  'daru',
#  'death',
#  'deceas',
#  'defi',
#  'democrat',
#  'denizen',
#  'depth',
#  'desir',
#  'desper',
#  'despit',
#  'determin',
#  'devic',
#  'differ',
#  'diminish',
#  'dirti',
#  'discov',
#  'disintegr',
#  'distress',
#  'district',
#  'diverg',
#  'doctor',
#  'doppelgang',
#  'drunken',
#  'dub',
#  'due',
#  'dynasti',
#  'earth',
#  'edo',
#  'edward',
#  'elder',
#  'elric',
#  'email',
#  'embark',
#  'embroil',
#  'emerg',
#  'emot',
#  'empir',
#  'enchousen',
#  'encount',
#  'encourag',
#  'endeavor',
#  'enemi',
#  'engin',
#  'equival',
#  'eren',
#  'etern',
#  'even',
#  'ever',
#  'everlast',
#  'everyth',
#  'ex',
#  'exam',
#  'exchang',
#  'exist',
#  'experi',
#  'extrem',
#  'face',
#  'famili',
#  'fantasi',
#  'far',
#  'fatal',
#  'fate',
#  'father',
#  'fear',
#  'feat',
#  'fellow',
#  'fight',
#  'fill',
#  'find',
#  'firm',
#  'first',
#  'fix',
#  'flashback',
#  'flee',
#  'flow',
#  'follow',
#  'forc',
#  'former',
#  'forward',
#  'found',
#  'four',
#  'fourth',
#  'fpa',
#  'free',
#  'freecss',
#  'freedom',
#  'friend',
#  'fullmet',
#  'fun',
#  'function',
#  'futur',
#  'gadget',
#  'gain',
#  'galact',
#  'galaxi',
#  'gate',
#  'gel',
#  'gem',
#  'generat',
#  'genius',
#  'genuin',
#  'get',
#  'gin',
#  'gintama',
#  'gintoki',
#  'give',
#  'goal',
#  'god',
#  'goe',
#  'golden',
#  'goldenbaum',
#  'gon',
#  'granddaught',
#  'green',
#  'grow',
#  'grown',
#  'hacker',
#  'hair',
#  'hand',
#  'happen',
#  'hardship',
#  'hashida',
#  'haunt',
#  'head',
#  'headquart',
#  'heart',
#  'heartfelt',
#  'help',
#  'hiatus',
#  'high',
#  'hijikata',
#  'hilari',
#  'histori',
#  'historian',
#  'hobbi',
#  'hold',
#  'home',
#  'honda',
#  'hope',
#  'horrif',
#  'household',
#  'howev',
#  'hulk',
#  'human',
#  'humor',
#  'hundr',
#  'hunter',
#  'ideal',
#  'idealist',
#  'ideolog',
#  'ignor',
#  'imagin',
#  'imposs',
#  'includ',
#  'incred',
#  'indulg',
#  'infam',
#  'inhabit',
#  'injur',
#  'instead',
#  'intens',
#  'interstellar',
#  'invent',
#  'isao',
#  'isol',
#  'itaru',
#  'japan',
#  'join',
#  'joke',
#  'journey',
#  'julian',
#  'kagura',
#  'kaiser',
#  'keep',
#  'key',
#  'killua',
#  'kintoki',
#  'kirchei',
#  'known',
#  'kondou',
#  'kurapika',
#  'kyojin',
#  'lab',
#  'law',
#  'leader',
#  'learn',
#  'left',
#  'leg',
#  'leorio',
#  'lie',
#  'life',
#  'lift',
#  'light',
#  'lightheart',
#  'like',
#  'limb',
#  'live',
#  'locat',
#  'lock',
#  'lohengramm',
#  'long',
#  'longer',
#  'loss',
#  'lost',
#  'love',
#  'lover',
#  'low',
#  'machin',
#  'mad',
#  'main',
#  'make',
#  'mal',
#  'mani',
#  'manner',
#  'maria',
#  'marri',
#  'mastermind',
#  'may',
#  'mayuri',
#  'mean',
#  'meanwhil',
#  'mechan',
#  'meet',
#  'member',
#  'merciless',
#  'metal',
#  'microwav',
#  'militari',
#  'mintz',
#  'miracul',
#  'misadventur',
#  'mission',
#  'mistak',
#  'moment',
#  'monster',
#  'morn',
#  'morph',
#  'mother',
#  'move',
#  'must',
#  'mysteri',
#  'nearbi',
#  'need',
#  'neighbor',
#  'new',
#  'next',
#  'nicknam',
#  'night',
#  'nitroplus',
#  'noth',
#  'notori',
#  'novel',
#  'odd',
#  'offici',
#  'okab',
#  'old',
#  'opposit',
#  'order',
#  'organ',
#  'ota',
#  'outer',
#  'outsid',
#  'overlord',
#  'pachinko',
#  'pack',
#  'paid',
#  'parodi',
#  'part',
#  'pass',
#  'past',
#  'path',
#  'perform',
#  'person',
#  'pervert',
#  'phenomenon',
#  'philosoph',
#  'phone',
#  'physic',
#  'pile',
#  'pinako',
#  'planet',
#  'play',
#  'plethora',
#  'plug',
#  'posit',
#  'possess',
#  'possibl',
#  'potenti',
#  'power',
#  'practic',
#  'pregnant',
#  'present',
#  'principl',
#  'probabl',
#  'proceed',
#  'proclaim',
#  'prodigi',
#  'progress',
#  'prohibit',
#  'promis',
#  'prospect',
#  'prosthet',
#  'protect',
#  'provid',
#  'punish',
#  'pupil',
#  'put',
#  'quest',
#  'rank',
#  'rate',
#  'reach',
#  'real',
#  'realiti',
#  'realiz',
#  'realli',
#  'realm',
#  'reason',
#  'rebelli',
#  'recent',
#  'red',
#  'refer',
#  'regain',
#  'reinhard',
#  'remain',
#  'rememb',
#  'remnant',
#  'rent',
#  'request',
#  'rescu',
#  'reserv',
#  'rest',
#  'restor',
#  'retak',
#  'return',
#  'revel',
#  'rewrit',
#  'ricketi',
#  'rintarou',
#  'robot',
#  'rockbel',
#  'room',
#  'ruler',
#  'sacrif',
#  'sacrific',
#  'safeguard',
#  'sakata',
#  'scheme',
#  'scientif',
#  'scientist',
#  'search',
#  'season',
#  'secret',
#  'seek',
#  'self',
#  'send',
#  'set',
#  'shackl',
#  'shall',
#  'shameless',
#  'shape',
#  'share',
#  'shiganshina',
#  'shiina',
#  'shimura',
#  'shingeki',
#  'shinpachi',
#  'shinsengumi',
#  'ship',
#  'shock',
#  'shoulder',
#  'show',
#  'side',
#  'siegfri',
#  'sign',
#  'simpl',
#  'sister',
#  'slapstick',
#  'slowli',
#  'smash',
#  'smooth',
#  'solut',
#  'soon',
#  'soul',
#  'souma',
#  'spaceship',
#  'special',
#  'spend',
#  'spirit',
#  'spur',
#  'stage',
#  'stagger',
#  'stalem',
#  'stalker',
#  'stand',
#  'standstil',
#  'startl',
#  'stay',
#  'stein',
#  'still',
#  'stone',
#  'strang',
#  'strateg',
#  'string',
#  'strive',
#  'strong',
#  'struggl',
#  'stumbl',
#  'success',
#  'sudden',
#  'suffer',
#  'suit',
#  'superpow',
#  'support',
#  'suppress',
#  'surfac',
#  'surpris',
#  'survey',
#  'suspici',
#  'sword',
#  'swore',
#  'take',
#  'task',
#  'tatter',
#  'team',
#  'tenac',
#  'territori',
#  'theori',
#  'though',
#  'thread',
#  'threaten',
#  'three',
#  'thrive',
#  'throne',
#  'throughout',
#  'time',
#  'tinker',
#  'titan',
#  'togeth',
#  'tongu',
#  'tooru',
#  'tough',
#  'toushirou',
#  'toward',
#  'town',
#  'tradit',
#  'tragic',
#  'train',
#  'tranquil',
#  'transform',
#  'transmut',
#  'treasur',
#  'tri',
#  'trio',
#  'trip',
#  'troubl',
#  'truli',
#  'twelv',
#  'two',
#  'unbeliev',
#  'uncertain',
#  'unchang',
#  'unchart',
#  'uncov',
#  'undergon',
#  'undesir',
#  'unexpect',
#  'unifi',
#  'unit',
#  'unlik',
#  'unoccupi',
#  'upon',
#  'use',
#  'usual',
#  'util',
#  'veng',
#  'versatil',
#  'vibrant',
#  'vice',
#  'victori',
#  'visual',
#  'vow',
#  'wall',
#  'warn',
#  'way',
#  'wen',
#  'whatev',
#  'winri',
#  'wit',
#  'wither',
#  'work',
#  'world',
#  'written',
#  'wrong',
#  'x',
#  'yang',
#  'yeager',
#  'year',
#  'yet',
#  'yorozuya',
#  'yoshiwara',
#  'young',
#  'zodiac'}

# %%
n=list(input().split(' '))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-188-a047a51607d3> in <module>
# ----> 1 n=list(input().split(' '))
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
inp = ['full','alchem','brother']

# %%
# Creates a list of list in which each sublist contains all the documents in which each word given appears
documents = []
for elem in inp:
    if elem in voc:
        documents.append(dic[voc[elem]])
    else:
        documents.append([])

# Confront all the words in the first sublist with all the other sublist and gives only the documents that contains
# all the words given in input

anime=[]                                              # Here we'll store the documents that contains all the words
if len(documents)<2:
    anime.append(documents)
else:
    for i in range(len(documents[0])):                    # for cicle to scroll over the elements of first sublist
        for j in range(1,len(documents)):                 # for cicle to check all other sublists
            l = 0                                         # counter used to check if a word is in all the lists
            if documents[0][i] in documents[j]:           # condition that if satisfied increase the counter
                l += 1
        if l == len(documents)-1:                         # condition that if satisfied append the document we are testing to list
            anime.append(documents[0][i])
            
print(anime)
# Out:
# []

# %%
documents
# Out:
# [[], ['anime_1'], ['anime_1']]

# %%
# Read url text file that we need in the final part
url = open(r'C:\Users\Leo\Documents\ADMHomework\ADM-HW3-master\links.txt',encoding = 'utf8')
urls = url.readlines()

# %%
# print all the information about all the anime that match all the key words
for elem in anime:
    n = int(''.join(filter(str.isdigit, elem)))-1       # take the number of each anime file and subtract 1 to get the right row
    print(Finaldata.iloc[n,0])                          # print the name of anime in row n
    print(Finaldata.iloc[n,1])                          # print the description of anime in row n
    print(urls[n][0:-1])                                # print the url (we stopped at -1 to avoid no-url symbols)
# Out:
# Fullmetal Alchemist: Brotherhood
# After a horrific alchemy experiment goes wrong in the Elric household, brothers Edward and Alphonse are left in a catastrophic new reality. Ignoring the alchemical principle banning human transmutation, the boys attempted to bring their recently deceased mother back to life. Instead, they suffered brutal personal loss: Alphonse's body disintegrated while Edward lost a leg and then sacrificed an arm to keep Alphonse's soul in the physical realm by binding it to a hulking suit of armor.The brothers are rescued by their neighbor Pinako Rockbell and her granddaughter Winry. Known as a bio-mechanical engineering prodigy, Winry creates prosthetic limbs for Edward by utilizing "automail," a tough, versatile metal used in robots and combat armor. After years of training, the Elric brothers set off on a quest to restore their bodies by locating the Philosopher's Stone—a powerful gem that allows an alchemist to defy the traditional laws of Equivalent Exchange.As Edward becomes an infamous alchemist and gains the nickname "Fullmetal," the boys' journey embroils them in a growing conspiracy that threatens the fate of the world.[Written by MAL Rewrite]
# https://myanimelist.net/anime/5114/Fullmetal_Alchemist__Brotherhood

# %%
Finaldata['Url'] = urls[0:9] # modify urls  when we use all the dataset

# %%
finded = []                                           # Creates a void list
for elem in anime:                                    # iterates through all intersect anime
    n = int(''.join(filter(str.isdigit, elem)))-1     # find the number in the document anime
    finded.append(n)                                  # append to the void list each of the values finded

Finaldata.iloc[finded]                                # returns only the rows that have matched
# Out:
#                          animeTitle  \
# 0  Fullmetal Alchemist: Brotherhood
#
#                                     animeDescription  \
# 0  After a horrific alchemy experiment goes wrong...
#
#                                                  Url
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...

# %%
# Exercise 2.2

# %%
from collections import Counter
import math

# %%
es22 = list()
for i in range(len(words)):
    c = Counter(words[i])
    es22.append(c)

# %%
D = len(words)
idf = []
for w in keywords:
    l=0
    for doc in words:
        if w in doc:
            l+=1
    idf.append(math.log10(D/l))

# %%
for c in es22:
    for word in c:
            i = 0
            c[word] = round(c[word]/len(c) * idf[i],2)
            i+=1

# %%
new = dict()
for i in range(len(words)):
    for word in words[i]:
        if voc[word] in new:
            new[voc[word]].append(['anime_'+str(i+1),es22[i][word]])
        else:
            new.update({voc[word]:[['anime_'+str(i+1),es22[i][word]]]})
